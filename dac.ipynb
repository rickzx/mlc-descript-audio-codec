# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from einops import rearrange
from torch.nn.utils import weight_norm

torch.manual_seed(0)

# Scripting this brings model speed up 1.4x
@torch.jit.script
def snake(x, alpha):
    shape = x.shape
    x = x.reshape(shape[0], shape[1], -1)
    x = x + (alpha + 1e-9).reciprocal() * torch.sin(alpha * x).pow(2)
    x = x.reshape(shape)
    return x


class Snake1d(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.alpha = nn.Parameter(torch.ones(1, channels, 1))

    def forward(self, x):
        return snake(x, self.alpha)

# %%
import torch
import torch.nn as nn
import time

data = torch.randn(1000, 1000, 1000)

snake_activation = Snake1d(channels=1000)

start = time.time()
output = snake_activation(data)
print("Elapsed time: ", time.time() - start)

print(output.shape)
print(output)
# Out:
# Elapsed time:  1.5504400730133057
# torch.Size([1000, 1000, 1000])
# tensor([[[-0.3111, -0.3175, -0.1891,  ...,  0.2749,  1.0751,  0.7834],
#          [ 0.4745,  0.8813,  0.0383,  ..., -0.2348,  0.0898, -0.2729],
#          [-0.0769,  2.2389,  1.1538,  ...,  1.1998, -0.2854, -0.1621],
#          ...,
#          [ 2.6884,  2.6729,  0.1439,  ...,  2.7138,  0.8706,  1.7031],
#          [-0.2212, -0.2856, -0.2735,  ..., -0.1797,  0.8550,  1.0921],
#          [-0.2160, -0.1768, -0.1945,  ..., -0.2739, -0.0183, -0.0271]],
#
#         [[ 0.2260,  0.7894, -2.3582,  ...,  1.7809, -0.2740,  0.2679],
#          [ 0.1190,  1.1279,  0.2607,  ...,  1.4119,  1.3101,  0.1124],
#          [ 1.3305,  2.7944, -0.2990,  ..., -0.2374, -0.3410, -0.2848],
#          ...,
#          [-0.2783,  0.5186,  1.4522,  ..., -0.1043,  1.9434,  2.7862],
#          [-0.2862,  2.7186,  2.6963,  ...,  1.3948, -0.2653, -0.2763],
#          [ 0.5810, -0.2649,  0.1593,  ..., -0.2854, -0.2772, -0.2845]],
#
#         [[ 2.0975, -0.2862, -0.2888,  ..., -0.2949,  0.2181, -0.2805],
#          [ 0.8453, -0.2834, -0.2906,  ...,  2.2783,  0.9943, -0.2859],
#          [ 0.0419, -0.0613, -1.1723,  ...,  2.5947,  2.7914, -0.2851],
#          ...,
#          [ 0.7910, -0.0383,  0.3689,  ..., -0.2133,  1.8968,  0.3157],
#          [ 0.3772,  2.5429, -0.2854,  ..., -0.2835,  0.9526,  0.1073],
#          [ 0.4389, -0.1973, -0.1200,  ...,  0.9997,  1.5016,  2.5336]],
#
#         ...,
#
#         [[ 0.3144, -0.2854,  0.3418,  ...,  1.6594,  0.7102,  0.1860],
#          [-0.1324, -0.2854,  0.2652,  ..., -1.4242, -0.2876,  0.1146],
#          [ 0.5936, -0.0329, -0.3352,  ...,  2.8513,  0.1164, -0.2814],
#          ...,
#          [ 2.8604,  2.7295, -0.2816,  ...,  1.0976,  0.3960, -0.2836],
#          [-0.0207, -0.2838, -0.1169,  ...,  0.9453,  2.0066, -0.3079],
#          [-0.2511, -0.3302,  2.0977,  ...,  2.1484,  1.5454,  2.6640]],
#
#         [[-0.3054, -0.2852,  2.6365,  ..., -0.0623, -0.2853,  2.5120],
#          [-0.2895, -0.3162, -0.2911,  ..., -0.5372, -0.2755,  1.1556],
#          [-0.0157, -0.2845, -0.1636,  ..., -0.1610, -0.2819, -0.0293],
#          ...,
#          [-0.2677,  0.3755, -0.0345,  ...,  0.7588, -0.2853,  0.4935],
#          [ 0.6189, -1.0768,  1.7441,  ...,  0.5052,  1.7285, -0.2987],
#          [ 1.9604, -0.3516, -0.2946,  ...,  0.3258,  2.7812, -0.0864]],
#
#         [[-0.2646,  0.3836,  0.7456,  ...,  0.2048, -1.3007, -0.2364],
#          [ 0.2540,  1.8637, -0.2666,  ..., -0.1049, -0.2852, -0.1835],
#          [-0.9474, -0.2939, -0.1156,  ..., -0.8204, -0.3221, -0.2853],
#          ...,
#          [-0.1151,  1.9315,  1.8993,  ..., -0.3358,  2.1801, -0.0761],
#          [-0.2753,  0.4121,  0.1358,  ..., -1.1755, -0.2844, -0.1735],
#          [ 0.9092, -1.4248, -0.2858,  ..., -0.2892, -1.6228, -1.4492]]],
#        grad_fn=<ViewBackward0>)

# %%
from typing import Optional
import tvm
from tvm import relax
from tvm.relax.frontend import nn
from tvm import te
from tvm import dlight as dl
from tvm.target import Target
import numpy as np

class Snake1d(nn.Module):
    def __init__(self, channels, dtype: Optional[str] = None):
        super().__init__()
        self.alpha = nn.Parameter((1, channels, 1), dtype)

    def forward(self, x: nn.Tensor):
        shape_x = x.shape
        x = nn.op.reshape(x, (shape_x[0], shape_x[1], -1))

        b, c, w = x.shape

        x = nn.op.tensor_expr_op(
            lambda x, alpha: te.compute(
                (b, c, w),
                lambda i, j, k: x[i, j, k] + 1 / (alpha[0, j, 0] + 1e-9) * te.power(te.sin(alpha[0, j, 0] * x[i, j, k]), 2),
                name="snake_compute",
            ),
            "snake",
            args=[x, self.alpha],
        )

        x = nn.op.reshape(x, shape_x)
        return x


mod_from_relax, params_from_relax = Snake1d(1000).export_tvm(
    {"forward": {"x": nn.spec.Tensor((1000, 1000, 1000), "float32")}}, debug=True
)
mod_from_relax.show()
print(params_from_relax)
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import relax as R</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func(private<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">snake</span>(reshape: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), alpha: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), snake_compute: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         <span style="color: #008000; font-weight: bold">for</span> i, j, k <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;snake_compute&quot;</span>):
#                 v_i, v_j, v_k <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>remap(<span style="color: #BA2121">&quot;SSS&quot;</span>, [i, j, k])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads(reshape[v_i, v_j, v_k], alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>writes(snake_compute[v_i, v_j, v_k])
#                 snake_compute[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">=</span> reshape[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0</span>) <span style="color: #AA22FF; font-weight: bold">/</span> (alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0000000000000001e-09</span>)) <span style="color: #AA22FF; font-weight: bold">*</span> T<span style="color: #AA22FF; font-weight: bold">.</span>pow(T<span style="color: #AA22FF; font-weight: bold">.</span>sin(alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">*</span> reshape[v_i, v_j, v_k]), T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">2.0</span>))
#
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">_initialize_effect</span>() <span style="color: #AA22FF; font-weight: bold">-&gt;</span> R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object):
#         <span style="color: #008000; font-weight: bold">with</span> R<span style="color: #AA22FF; font-weight: bold">.</span>dataflow():
#             _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>null_value()
#             lv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> (_io,)
#             gv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> lv
#             R<span style="color: #AA22FF; font-weight: bold">.</span>output(gv)
#         <span style="color: #008000; font-weight: bold">return</span> gv
#
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">forward</span>(x: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1000</span>, <span style="color: #008000">1000</span>, <span style="color: #008000">1000</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object, alpha: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">1000</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>)) <span style="color: #AA22FF; font-weight: bold">-&gt;</span> R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1000</span>, <span style="color: #008000">1000</span>, <span style="color: #008000">1000</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</sp
# [('alpha', Tensor([1, 1000, 1], "float32"))]

# %%
target = Target.from_device("metal")
print(target)
with target:
    mod = relax.transform.LegalizeOps()(mod_from_relax)
    mod = dl.ApplyDefaultSchedule(
        dl.gpu.Matmul(),
        dl.gpu.GEMV(),
        dl.gpu.Reduction(),
        dl.gpu.GeneralReduction(),
        dl.gpu.Fallback(),
    )(mod)
ex = relax.build(mod, target)
device = tvm.metal()

vm = relax.VirtualMachine(ex, device)
tvm_data = tvm.nd.array(data, device=device)
params = [np.ones(param.shape).astype("float32") for _, param in params_from_relax]
params = [tvm.nd.array(param, device=device) for param in params]

start = time.time()
effects = vm["_initialize_effect"]()
output_tvm = vm["forward"](tvm_data, *effects, *params)[0].numpy()
print("Elapsed time: ", time.time() - start)

print(output_tvm.shape)
print(output_tvm)
# Out:
# metal -keys=metal,gpu -max_function_args=31 -max_num_threads=256 -max_shared_memory_per_block=32768 -max_threads_per_block=1024 -thread_warp_size=32
# Elapsed time:  0.7192351818084717
# (1000, 1000, 1000)
# [[[-0.31110036 -0.3174659  -0.18909222 ...  0.274942    1.0750501
#     0.7834442 ]
#   [ 0.47453836  0.8813273   0.03826318 ... -0.23482114  0.08977266
#    -0.27293307]
#   [-0.07691161  2.2388506   1.1538075  ...  1.1998394  -0.28540426
#    -0.16207218]
#   ...
#   [ 2.6884463   2.6729436   0.14385073 ...  2.7138073   0.87058294
#     1.7030883 ]
#   [-0.22119421 -0.28558815 -0.2735336  ... -0.17965236  0.8549696
#     1.0920608 ]
#   [-0.21595624 -0.17683856 -0.19451383 ... -0.2739008  -0.01827374
#    -0.02706373]]
#
#  [[ 0.22597633  0.7893648  -2.3581793  ...  1.780864   -0.2739746
#     0.2679049 ]
#   [ 0.11902615  1.1279249   0.26066315 ...  1.4119387   1.3100795
#     0.11241668]
#   [ 1.3304498   2.7944255  -0.2990268  ... -0.23743066 -0.34098005
#    -0.28483236]
#   ...
#   [-0.2782858   0.51855546  1.4522367  ... -0.10431571  1.943394
#     2.7861829 ]
#   [-0.2862357   2.718574    2.6963181  ...  1.3948143  -0.26532474
#    -0.2763283 ]
#   [ 0.5810276  -0.2648732   0.15925018 ... -0.28540516 -0.27722389
#    -0.28454533]]
#
#  [[ 2.0975409  -0.2861715  -0.2888438  ... -0.29489625  0.21810767
#    -0.28052562]
#   [ 0.84528804 -0.283444   -0.29063624 ...  2.2783036   0.99428093
#    -0.2858793 ]
#   [ 0.04187727 -0.06130701 -1.1722932  ...  2.594665    2.791408
#    -0.28512108]
#   ...
#   [ 0.79100585 -0.03834405  0.3688742  ... -0.21328828  1.8967884
#     0.31567928]
#   [ 0.37715873  2.5429363  -0.2853909  ... -0.2835064   0.9526067
#     0.10729507]
#   [ 0.43887487 -0.19726288 -0.11996377 ...  0.9996985   1.5016
#     2.5335693 ]]
#
#  ...
#
#  [[ 0.31442678 -0.28537902  0.3418219  ...  1.6594031   0.7102055
#     0.18603212]
#   [-0.13236685 -0.28539574  0.265201   ... -1.4242401  -0.2876315
#     0.11458141]
#   [ 0.59355307 -0.03290117 -0.33522767 ...  2.8513112   0.11642715
#    -0.2813638 ]
#   ...
#   [ 2.8603919   2.7295194  -0.2816207  ...  1.0976007   0.39601296
#    -0.28355813]
#   [-0.02069522 -0.28380767 -0.11693338 ...  0.9453181   2.0065892
#    -0.30786347]
#   [-0.25106776 -0.33022457  2.0976872  ...  2.1483717   1.5453925
#     2.6640494 ]]
#
#  [[-0.30543935 -0.2852325   2.6365278  ... -0.06234986 -0.28531015
#     2.511989  ]
#   [-0.28951746 -0.31622988 -0.29111236 ... -0.5371928  -0.27549782
#     1.1555933 ]
#   [-0.01573962 -0.28446978 -0.16360557 ... -0.16097693 -0.28193003
#    -0.02934633]
#   ...
#   [-0.2677334   0.37553632 -0.03453101 ...  0.7587518  -0.28525093
#     0.49353302]
#   [ 0.61886674 -1.0768284   1.7440703  ...  0.50521106  1.7285497
#    -0.2987265 ]
#   [ 1.9603758  -0.351614   -0.2945851  ...  0.32584354  2.7812197
#    -0.0864037 ]]
#
#  [[-0.2645767   0.38356292  0.74555296 ...  0.20483248 -1.3007305
#    -0.23640786]
#   [ 0.25396633  1.8636991  -0.26656723 ... -0.10494645 -0.28524974
#    -0.18347235]
#   [-0.94742805 -0.29393274 -0.11564075 ... -0.8204372  -0.32206947
#    -0.285293  ]
#   ...
#   [-0.11511009  1.9314942   1.899252   ... -0.33583015  2.1801188
#    -0.0760752 ]
#   [-0.2753094   0.41211635  0.13578314 ... -1.1754739  -0.28443676
#    -0.17349318]
#   [ 0.909202   -1.4247917  -0.28582013 ... -0.28921306 -1.6227801
#    -1.4491801 ]]]

# %%
np.testing.assert_allclose(output.detach().numpy(), output_tvm, atol=1e-5, rtol=1e-5)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from einops import rearrange
from torch.nn.utils import weight_norm


def WNConv1d(*args, **kwargs):
    conv1d = nn.Conv1d(*args, **kwargs)
    print("original shape: ", conv1d.weight.shape)
    return weight_norm(conv1d)

# %%
wn_conv1d = WNConv1d(5, 10, 10)

torch.manual_seed(0)

weight_g_data = torch.randn(10, 1, 1)
weight_v_data = torch.randn(10, 5, 10)
bias_data = torch.randn(10)
wn_conv1d.weight_g.data = weight_g_data
wn_conv1d.weight_v.data = weight_v_data
wn_conv1d.bias.data = bias_data

print(wn_conv1d.weight_g.shape, wn_conv1d.weight_v.shape)
print(wn_conv1d.bias.shape)
data = torch.randn(20, 5, 1000)
out = wn_conv1d(data)
print(out.shape)
print(out)
# Out:
# original shape:  torch.Size([10, 5, 10])
# torch.Size([10, 1, 1]) torch.Size([10, 5, 10])
# torch.Size([10])
# torch.Size([20, 10, 991])
# tensor([[[ 2.1434e+00, -5.5163e-01,  1.8618e+00,  ...,  5.8507e-01,
#            1.2631e+00,  3.9047e+00],
#          [ 2.1691e-01,  1.2649e-01, -3.3990e-01,  ...,  2.6183e-02,
#           -1.6413e-01, -7.1865e-01],
#          [-8.9280e-02,  1.3261e-01, -1.6264e+00,  ...,  2.2662e-02,
#            1.9311e+00, -5.4569e-01],
#          ...,
#          [ 4.1833e-02, -3.0315e-02, -1.4764e+00,  ..., -3.6672e-01,
#           -1.7967e+00, -5.0222e-01],
#          [ 1.7244e+00,  2.2790e+00,  4.6369e-01,  ...,  1.3250e+00,
#            8.8640e-01,  1.9802e+00],
#          [-5.5861e-01, -3.4076e-01, -6.6874e-01,  ..., -5.5540e-01,
#           -1.1855e+00, -4.3219e-01]],
#
#         [[ 3.9408e+00,  1.7900e+00,  1.3604e+00,  ...,  9.8031e-01,
#            3.2566e-01,  3.1830e+00],
#          [-3.9300e-01, -6.3680e-01, -4.0502e-01,  ..., -2.1011e-01,
#            1.8975e-02, -1.6795e-01],
#          [ 1.4103e+00, -1.2779e+00,  1.6178e+00,  ..., -2.1078e+00,
#           -2.7984e+00, -7.1433e-01],
#          ...,
#          [-3.1557e-01, -9.1505e-01, -4.2537e-01,  ..., -1.9691e-02,
#            3.9169e-01,  3.6474e-01],
#          [ 2.3033e+00, -5.0895e-01,  2.0037e+00,  ...,  1.8502e+00,
#            1.3361e+00,  2.0437e+00],
#          [-4.3276e-01, -1.0081e+00, -1.7225e-01,  ..., -8.7434e-01,
#           -7.8212e-01, -7.3967e-01]],
#
#         [[ 1.1352e+00,  2.5821e+00,  1.3859e+00,  ..., -1.1025e+00,
#            3.6016e-01,  1.5455e+00],
#          [-1.5074e-01, -4.3295e-01,  2.9650e-01,  ..., -6.9871e-02,
#            4.4236e-01,  1.4897e-01],
#          [ 2.8567e-02, -1.5967e+00, -5.0780e-03,  ..., -3.2973e+00,
#            3.4491e+00, -1.1719e+00],
#          ...,
#          [-9.3187e-01,  8.2979e-02, -1.6959e-01,  ..., -7.7423e-01,
#           -1.2212e+00, -1.6107e+00],
#          [ 4.9391e-02,  1.5304e+00,  1.6349e+00,  ...,  1.2081e+00,
#            1.4269e+00,  1.8364e+00],
#          [-5.5813e-01, -2.2117e-01, -8.0762e-01,  ..., -1.0316e+00,
#           -3.6370e-01, -8.2103e-01]],
#
#         ...,
#
#         [[-1.3914e+00,  4.2410e-01,  2.6283e+00,  ...,  1.3126e+00,
#            8.5346e-02,  5.3646e-01],
#          [-5.4183e-01, -3.1087e-01,  2.7118e-01,  ..., -3.2940e-01,
#           -1.9892e-01,  1.1702e-01],
#          [-1.5402e+00,  3.9522e+00,  1.3856e+00,  ..., -1.7163e+00,
#            8.2230e-01,  1.9116e+00],
#          ...,
#          [-9.1339e-02,  2.2255e-01,  3.0885e-01,  ...,  7.6300e-01,
#            2.7968e-01, -1.8150e-01],
#          [ 6.6170e-01,  1.3374e+00,  2.0900e+00,  ...,  1.3303e+00,
#            1.1281e+00,  1.5320e+00],
#          [-5.2997e-01, -3.6777e-01, -9.3318e-01,  ..., -9.6121e-01,
#           -5.5352e-02, -7.2768e-01]],
#
#         [[ 3.4492e+00,  9.8606e-01, -4.1684e-01,  ...,  1.9659e+00,
#            1.7782e+00, -6.9200e-01],
#          [-2.0436e-03, -3.5293e-01,  3.9011e-02,  ..., -8.5184e-01,
#           -3.1265e-01, -2.1414e-01],
#          [ 2.5074e+00,  2.7631e+00,  3.3599e+00,  ...,  8.9522e-01,
#            8.5174e-01, -7.7222e-01],
#          ...,
#          [-4.9164e-01,  2.8958e-01,  3.2755e-01,  ...,  1.8172e+00,
#            3.2008e-01,  2.4495e-02],
#          [ 1.3861e+00,  5.9357e-01,  1.7257e+00,  ...,  2.8371e+00,
#            1.3281e+00,  7.8434e-01],
#          [ 3.9422e-01, -1.2791e+00, -5.6725e-01,  ..., -7.3831e-01,
#           -6.5319e-01, -9.0067e-01]],
#
#         [[ 2.4333e+00, -8.5475e-01,  2.0438e+00,  ...,  8.9005e-01,
#            2.4094e+00,  7.4997e-01],
#          [-4.9506e-01,  3.3638e-01, -9.9790e-02,  ..., -2.0324e-01,
#           -1.1781e-01, -3.4515e-01],
#          [-1.1147e+00,  1.1114e+00, -1.0563e+00,  ..., -4.2484e+00,
#           -1.1571e+00,  1.7826e+00],
#          ...,
#          [ 1.2423e-01,  5.8577e-01,  5.8028e-01,  ...,  1.2453e+00,
#           -1.0802e+00, -9.4489e-01],
#          [ 2.3092e+00,  2.0060e-01,  3.0432e+00,  ...,  2.4856e+00,
#            1.8609e+00,  7.3030e-01],
#          [ 1.7454e-01, -8.5550e-01, -3.6029e-01,  ..., -8.3615e-01,
#           -4.6733e-01, -1.2531e+00]]], grad_fn=<ConvolutionBackward0>)
# /Users/cfruan/miniconda3/envs/mlc-audio/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:135: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
from typing import Optional
import tvm
from tvm import relax
from tvm.relax.frontend import nn
from tvm.relax import expr as _expr
from tvm.relax import op as _op
from tvm import te
from tvm import dlight as dl
from tvm.target import Target
import numpy as np
import time

class WNConv1d(nn.Module):
    """
    Module for conv1d layer.
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int,
        stride: int = 1,
        padding: int = 0,
        dilation: int = 1,
        groups: int = 1,
        bias: bool = True,
        dtype: Optional[str] = None,
    ) -> None:
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        self.dilation = dilation
        self.groups = groups
        self.dtype = dtype

        self.weight_g = nn.Parameter(
            (
                self.out_channels,
                1,
                1,
            ),
            dtype,
        )

        self.weight_v = nn.Parameter(
            (
                self.out_channels,
                self.in_channels // self.groups,
                self.kernel_size,
            ),
            dtype,
        )
        if bias:
            self.bias = nn.Parameter((self.out_channels,), dtype)
        else:
            self.bias = None

    def forward(self, x: nn.Tensor) -> nn.Tensor:
        """
        Forward method for conv1d layer.

        Parameters
        ----------
        x : Tensor
            The input tensor.

        Returns
        -------
        ret : Tensor
            The output tensor for the conv1d layer.
        """
        dim = [i for i in range(1, x.ndim)]
        norm_v = _op.sqrt(
            _op.sum(_op.square(self.weight_v._expr), axis=dim, keepdims=True),
        )
        weight = nn.wrap_nested(
            self.weight_g._expr * (self.weight_v._expr / norm_v), name="wnconv1d"
        )
        return nn.op.conv1d(
            x, weight, self.bias, self.stride, self.padding, self.dilation, self.groups
        )

mod_from_relax, params_from_relax = WNConv1d(5, 10, 10).export_tvm(
    {"forward": {"x": nn.spec.Tensor((20, 5, 1000), "float32")}}, debug=True
)
mod_from_relax.show()
print(params_from_relax)
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import relax as R</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">_initialize_effect</span>() <span style="color: #AA22FF; font-weight: bold">-&gt;</span> R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object):
#         <span style="color: #008000; font-weight: bold">with</span> R<span style="color: #AA22FF; font-weight: bold">.</span>dataflow():
#             _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>null_value()
#             lv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> (_io,)
#             gv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> lv
#             R<span style="color: #AA22FF; font-weight: bold">.</span>output(gv)
#         <span style="color: #008000; font-weight: bold">return</span> gv
#
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">forward</span>(x: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">20</span>, <span style="color: #008000">5</span>, <span style="color: #008000">1000</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object, weight_g: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), weight_v: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>, <span style="color: #008000">5</span>, <span style="color: #008000">10</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), bias: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>,), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>)) <span style="color: #AA22FF; font-weight: bold">-&gt;</span> R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">20</span>, <span style="color: #008000">10</span>, <span style="color: #008000">991</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object)):
#         R<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;num_input&quot;</span>: <span style="color: #008000">2</span>})
#         <span style="color: #008000; font-weight: bold">with</span> R<span style="color: #AA22FF; font-weight: bold">.</span>dataflow():
#             lv1: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>, <span style="color: #008000">5</span>, <span style="color: #008000">10</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>square(weight_v)
#             lv2: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>sum(lv1, axis<span style="color: #AA22FF; font-weight: bold">=</span>[<span style="color: #008000">1</span>, <span style="color: #008000">2</span>], keepdims<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#             lv3: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>sqrt(lv2)
#             lv4: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>, <span style="color: #008000">5</span>, <span style="color: #008000">10</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>divide(weight_v, lv3)
#             wnconv1d: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">10</span>, <span style="color: #008000">5</span>, <span style="color: #008000">10</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>multiply(weight_g, lv4)
#             lv5: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">20</span>, <span style="color: #008000">10</span>, <span style="color: #008000">991</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>) <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>nn<span style="color: #AA22FF; font-weight: bold">.</span>conv1d(x, wnconv1d, strides<span style="color: #AA22FF; font-weight: bold">=</span>[<span style="color: #008000">1</span>], padding<span style="color: #AA22FF; font-weight: bold">=</span>[<span style="color: #008000">0</span>, <span style="color: #008000">0</span>], dilation<span style="color: #AA22FF; font-weight: bold">=</span>[<span style="color: #008000">1</span>], groups<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000">1</span>, data_layout<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;NCW&quot;</span>, kernel_layout<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;OIW&quot;</span>, out_layout<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;NCW&quot;</span>, o
# [('weight_g', Tensor([10, 1, 1], "float32")), ('weight_v', Tensor([10, 5, 10], "float32")), ('bias', Tensor([10], "float32"))]

# %%
target = Target.from_device("metal")
print(target)
with target:
    mod = relax.transform.LegalizeOps()(mod_from_relax)
    mod = dl.ApplyDefaultSchedule(
        # dl.gpu.Matmul(),
        # dl.gpu.GEMV(),
        # dl.gpu.Reduction(),
        # dl.gpu.GeneralReduction(),
        # dl.gpu.Fallback(),
    )(mod)
mod.show()
ex = relax.build(mod, target)
print(ex.mod.imported_modules[0].imported_modules[0].get_source())
device = tvm.metal()

vm = relax.VirtualMachine(ex, device)
tvm_data = tvm.nd.array(data, device=device)
print(params_from_relax)
params = [weight_g_data.numpy().astype("float32"), weight_v_data.numpy().astype("float32"), bias_data.numpy().astype("float32")]
params = [tvm.nd.array(param, device=device) for param in params]

start = time.time()
effects = vm["_initialize_effect"]()
output_tvm = vm["forward"](tvm_data, *effects, *params)[0].numpy()
print("Elapsed time: ", time.time() - start)

# print(params)

# print(output_tvm.shape)
# print(output_tvm)
# Out:
# metal -keys=metal,gpu -max_function_args=31 -max_num_threads=256 -max_shared_memory_per_block=32768 -max_threads_per_block=1024 -thread_warp_size=32
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import relax as R</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func(private<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">add</span>(lv5: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">20</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">10</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">991</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), lv6: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">10</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), T_add: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">20</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">10</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">991</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         <span style="color: #008000; font-weight: bold">for</span> ax0, ax1, ax2 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">20</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">10</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">991</span>)):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;T_add&quot;</span>):
#                 v_ax0, v_ax1, v_ax2 <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>remap(<span style="color: #BA2121">&quot;SSS&quot;</span>, [ax0, ax1, ax2])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads(lv5[v_ax0, v_ax1, v_ax2], lv6[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_ax1, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>writes(T_add[v_ax0, v_ax1, v_ax2])
#                 T_add[v_ax0, v_ax1, v_ax2] <span style="color: #AA22FF; font-weight: bold">=</span> lv5[v_ax0, v_ax1, v_ax2] <span style="color: #AA22FF; font-weight: bold">+</span> lv6[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_ax1, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)]
#
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func(private<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">conv1d</span>(x: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">20</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">5</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), wnconv1d: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">10</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">5</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">10</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), conv1d_ncw: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">20</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">10</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">991</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         pad_temp <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>alloc_buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">20</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">5</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)))
#         <span style="color: #008000; font-weight: bold">for</span> i0, i1, i2 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">20</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">5</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;pad_temp&quot;</span>):
#                 v_i0, v_i1, v_i2 <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>remap(<span style="color: #BA2121">&quot;SSS&quot;</span>, [i0, i1, i2])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads(x[v_i0, v_
# ---------------------------------------------------------------------------
# TVMError                                  Traceback (most recent call last)
# Cell In[14], line 13
#       5     mod = dl.ApplyDefaultSchedule(
#       6         # dl.gpu.Matmul(),
#       7         # dl.gpu.GEMV(),
#    (...)
#      10         # dl.gpu.Fallback(),
#      11     )(mod)
#      12 mod.show()
# ---> 13 ex = relax.build(mod, target)
#      14 print(ex.mod.imported_modules[0].imported_modules[0].get_source())
#      15 device = tvm.metal()
#
# File ~/Documents/tvm-unity/python/tvm/relax/vm_build.py:353, in build(mod, target, params, pipeline, exec_mode, system_lib)
#     351 builder = relax.ExecBuilder()
#     352 mod = _vmcodegen(builder, mod, exec_mode)
# --> 353 return _vmlink(
#     354     builder=builder,
#     355     target=target,
#     356     tir_mod=_filter_tir(mod),
#     357     ext_libs=ext_libs,
#     358     params=params,
#     359     system_lib=system_lib,
#     360 )
#
# File ~/Documents/tvm-unity/python/tvm/relax/vm_build.py:249, in _vmlink(builder, target, tir_mod, ext_libs, params, system_lib)
#     247 tir_ext_libs = []
#     248 if tir_mod is not None and len(tir_mod.get_global_vars()) > 0:
# --> 249     lib = tvm.build(
#     250         tir_mod,
#     251         target=target,
#     252         runtime=_autodetect_system_lib_req(target, system_lib),
#     253     )
#     254 for ext_mod in ext_libs:
#     255     if ext_mod.is_device_module:
#
# File ~/Documents/tvm-unity/python/tvm/driver/build_module.py:297, in build(inputs, args, target, target_host, runtime, name, binds)
#     293     target_host = "llvm" if tvm.runtime.enabled("llvm") else "stackvm"
#     295 annotated_mods, target_host = Target.canon_target_map_and_host(annotated_mods, target_host)
# --> 297 rt_mod_host = _driver_ffi.tir_to_runtime(annotated_mods, target_host)
#     299 annotated_mods, target_host = Target.canon_target_map_and_host(annotated_mods, target_host)
#     301 if not isinstance(target_host, Target):
#
# File ~/Documents/tvm-unity/python/tvm/_ffi/_ctypes/packed_func.py:245, in PackedFuncBase.__call__(self, *args)
#     233 ret_tcode = ctypes.c_int()
#     234 if (
#     235     _LIB.TVMFuncCall(
#     236         self.handle,
#    (...)
#     243     != 0
#     244 ):
# --> 245     raise_last_ffi_error()
#     246 _ = temp_args
#     247 _ = args
#
# File ~/Documents/tvm-unity/python/tvm/_ffi/base.py:481, in raise_last_ffi_error()
#     475 # The exception PyObject may contain a large amount of state,
#     476 # including all stack frames that may be inspected in a later
#     477 # PDB post-mortem.  Therefore, we must make sure to remove the
#     478 # underlying PyObject* from the C++ side after we retrieve it.
#     479 _LIB.TVMDropLastPythonError()
# --> 481 raise py_err
#
# File ~/Documents/tvm-unity/src/driver/driver_api.cc:531, in tvm::$_5::operator()(tvm::runtime::Map<tvm::Target, tvm::IRModule, void, void> const&, tvm::Target) const()
#     529 TVM_REGISTER_GLOBAL("driver.tir_to_runtime")
#     530     .set_body_typed([](const Map<Target, IRModule>& inputs_arg, Target host_target) {
# --> 531       return TIRToRuntime(inputs_arg, host_target);
#     532     });
#     533
#
# File ~/Documents/tvm-unity/src/driver/driver_api.cc:492, in tvm::TIRToRuntime(tvm::runtime::Map<tvm::Target, tvm::IRModule, void, void> const&, tvm::Target const&)()
#     490 const Target& target = it.first;
#     491 const IRModule& ir_module = it.second;
# --> 492 auto pair = SplitMixedModule(ir_module, target, target_host);
#     493 auto& host_mod = pair.first;
#     494 auto& device_mod = pair.second;
#
# File ~/Documents/tvm-unity/src/driver/driver_api.cc:418, in tvm::SplitMixedModule(tvm::IRModule, tvm::Target const&, tvm::Target const&)()
#     416 ICHECK(mod_mixed.defined()) << "This module must be defined";
#     417
# --> 418 mod_mixed = ApplyPasses(mod_mixed, MixedModulePassManager(mod_mixed, target));
#     419
#     420 IRModule host_mod = ApplyPasses(mod_mixed, HostModulePassManager(mod_mixed, target_host));
#
# File ~/Documents/tvm-unity/src/driver/driver_api.cc:291, in tvm::ApplyPasses(tvm::IRModule, tvm::transform::Sequential)()
#     289
#     290 IRModule ApplyPasses(IRModule mod, transform::Sequential seq) {
# --> 291   mod = seq(std::move(mod));
#     292   return mod;
#     293 }
#
# File ~/Documents/tvm-unity/src/tir/analysis/verify_memory.cc:205, in tvm::tir::transform::VerifyMemory()::$_0::operator()(tvm::IRModule, tvm::transform::PassContext) const()
#     203   s << "    " << err << "\n";
#     204 }
# --> 205 LOG(FATAL) << "RuntimeError: Memory verification failed with the following errors:\n"
#     206            << s.str() << "  Did you forget to bind?\n"
#     207            << func;
#
# TVMError: Traceback (most recent call last):
#   4: tvm::$_5::operator()(tvm::runtime::Map<tvm::Target, tvm::IRModule, void, void> const&, tvm::Target) const
#         at /Users/cfruan/Documents/tvm-unity/src/driver/driver_api.cc:531
#   3: tvm::TIRToRuntime(tvm::runtime::Map<tvm::Target, tvm::IRModule, void, void> const&, tvm::Target const&)
#         at /Users/cfruan/Documents/tvm-unity/src/driver/driver_api.cc:492
#   2: tvm::SplitMixedModule(tvm::IRModule, tvm::Target const&, tvm::Target const&)
#         at /Users/cfruan/Documents/tvm-unity/src/driver/driver_api.cc:418
#   1: tvm::ApplyPasses(tvm::IRModule, tvm::transform::Sequential)
#         at /Users/cfruan/Documents/tvm-unity/src/driver/driver_api.cc:291
#   0: tvm::tir::transform::VerifyMemory()::$_0::operator()(tvm::IRModule, tvm::transform::PassContext) const
#         at /Users/cfruan/Documents/tvm-unity/src/tir/analysis/verify_memory.cc:205
#   Did you forget to bind?
#     Variable `lv2` is directly accessed by host memory (it is not contained in a thread environment or in the function arguments.
#     Variable `compute` is directly accessed by host memory (it is not contained in a thread environment or in the function arguments.
#   File "/Users/cfruan/Documents/tvm-unity/src/tir/analysis/verify_memory.cc", line 205
# RuntimeError: Memory verification failed with the following errors:
# # from tvm.script import tir as T
#
# @T.prim_func
# def tir_sqrt(lv2: T.Buffer((T.int64(10), T.int64(1), T.int64(1)), "float32"), compute: T.Buffer((T.int64(10), T.int64(1), T.int64(1)), "float32")):
#     T.func_attr({"target": T.target({"host": {"keys": ["arm_cpu", "cpu"], "kind": "llvm", "mtriple": "arm64-apple-darwin22.5.0", "tag": ""}, "keys": ["metal", "gpu"], "kind": "metal", "max_function_args": 31, "max_num_threads": 256, "max_shared_memory_per_block": 32768, "max_threads_per_block": 1024, "tag": "", "thread_warp_size": 32}), "tir.noalias": T.bool(True)})
#     for i0 in range(10):
#         compute_1 = T.Buffer((T.int64(10),), data=compute.data)
#         lv2_1 = T.Buffer((T.int64(10),), data=lv2.data)
#         compute_1[i0] = T.sqrt(lv2_1[i0])

# %%
class ResidualUnit(nn.Module):
    def __init__(self, dim: int = 16, dilation: int = 1):
        pad = ((7 - 1) * dilation) // 2
        self.block = nn.ModuleList(
            [
                Snake1d(dim),
                WNConv1d(dim, dim, kernel_size=7, dilation=dilation, padding=pad),
                Snake1d(dim),
                WNConv1d(dim, dim, kernel_size=1),
            ]
        )

    def forward(self, x: nn.Tensor):
        residual = x
        for layer in self.block:
            x = layer(x)
        return x + residual
    
mod_from_relax, params_from_relax = ResidualUnit().export_tvm(
    {"forward": {"x": nn.spec.Tensor((32, 16, 1000), "float32")}}, debug=True
)
mod_from_relax.show()
print(params_from_relax)
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import relax as R</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func(private<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">snake</span>(reshape: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">16</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), block_0_alpha: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">16</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), snake_compute: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">16</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         <span style="color: #008000; font-weight: bold">for</span> i, j, k <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">16</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;snake_compute&quot;</span>):
#                 v_i, v_j, v_k <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>remap(<span style="color: #BA2121">&quot;SSS&quot;</span>, [i, j, k])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads(reshape[v_i, v_j, v_k], block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>writes(snake_compute[v_i, v_j, v_k])
#                 snake_compute[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">=</span> reshape[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0</span>) <span style="color: #AA22FF; font-weight: bold">/</span> (block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0000000000000001e-09</span>)) <span style="color: #AA22FF; font-weight: bold">*</span> T<span style="color: #AA22FF; font-weight: bold">.</span>pow(T<span style="color: #AA22FF; font-weight: bold">.</span>sin(block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">*</span> reshape[v_i, v_j, v_k]), T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">2.0</span>))
#
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">_initialize_effect</span>() <span style="color: #AA22FF; font-weight: bold">-&gt;</span> R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object):
#         <span style="color: #008000; font-weight: bold">with</span> R<span style="color: #AA22FF; font-weight: bold">.</span>dataflow():
#             _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>null_value()
#             lv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> (_io,)
#             gv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> lv
#             R<span style="color: #AA22FF; font-weight: bold">.</span>output(gv)
#         <span style="color: #008000; font-weight: bold">return</span> gv
#
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">forward</span>(x: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">32</span>, <span style="color: #008000">16</span>, <span style="color: #008000">1000</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object, block_0_alpha: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">16</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), block_1_weight_g: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), block_1_weight_v: R<span style="c
# [('block.0.alpha', Tensor([1, 16, 1], "float32")), ('block.1.weight_g', Tensor([16, 1, 1], "float32")), ('block.1.weight_v', Tensor([16, 16, 7], "float32")), ('block.1.bias', Tensor([16], "float32")), ('block.2.alpha', Tensor([1, 16, 1], "float32")), ('block.3.weight_g', Tensor([16, 1, 1], "float32")), ('block.3.weight_v', Tensor([16, 16, 1], "float32")), ('block.3.bias', Tensor([16], "float32"))]

# %%
import math

class EncoderBlock(nn.Module):
    def __init__(self, dim: int = 16, stride: int = 1):
        self.block = nn.ModuleList(
            [
                ResidualUnit(dim // 2, dilation=1),
                ResidualUnit(dim // 2, dilation=3),
                ResidualUnit(dim // 2, dilation=9),
                Snake1d(dim // 2),
                WNConv1d(
                    dim // 2,
                    dim,
                    kernel_size=2 * stride,
                    stride=stride,
                    padding=math.ceil(stride / 2),
                ),
            ]
        )

    def forward(self, x):
        for layer in self.block:
            x = layer(x)
        return x
    
mod_from_relax, params_from_relax = EncoderBlock().export_tvm(
    {"forward": {"x": nn.spec.Tensor((32, 8, 1000), "float32")}}, debug=True
)
mod_from_relax.show()
print(params_from_relax)
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import relax as R</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func(private<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">snake</span>(reshape: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">8</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), block_0_block_0_alpha: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">8</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), snake_compute: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">8</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         <span style="color: #008000; font-weight: bold">for</span> i, j, k <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">8</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1000</span>)):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;snake_compute&quot;</span>):
#                 v_i, v_j, v_k <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>remap(<span style="color: #BA2121">&quot;SSS&quot;</span>, [i, j, k])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads(reshape[v_i, v_j, v_k], block_0_block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>writes(snake_compute[v_i, v_j, v_k])
#                 snake_compute[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">=</span> reshape[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0</span>) <span style="color: #AA22FF; font-weight: bold">/</span> (block_0_block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0000000000000001e-09</span>)) <span style="color: #AA22FF; font-weight: bold">*</span> T<span style="color: #AA22FF; font-weight: bold">.</span>pow(T<span style="color: #AA22FF; font-weight: bold">.</span>sin(block_0_block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">*</span> reshape[v_i, v_j, v_k]), T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">2.0</span>))
#
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">_initialize_effect</span>() <span style="color: #AA22FF; font-weight: bold">-&gt;</span> R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object):
#         <span style="color: #008000; font-weight: bold">with</span> R<span style="color: #AA22FF; font-weight: bold">.</span>dataflow():
#             _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object <span style="color: #AA22FF; font-weight: bold">=</span> R<span style="color: #AA22FF; font-weight: bold">.</span>null_value()
#             lv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> (_io,)
#             gv: R<span style="color: #AA22FF; font-weight: bold">.</span>Tuple(R<span style="color: #AA22FF; font-weight: bold">.</span>Object) <span style="color: #AA22FF; font-weight: bold">=</span> lv
#             R<span style="color: #AA22FF; font-weight: bold">.</span>output(gv)
#         <span style="color: #008000; font-weight: bold">return</span> gv
#
#     <span style="color: #AA22FF">@R</span><span style="color: #AA22FF; font-weight: bold">.</span>function
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">forward</span>(x: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">32</span>, <span style="color: #008000">8</span>, <span style="color: #008000">1000</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), _io: R<span style="color: #AA22FF; font-weight: bold">.</span>Object, block_0_block_0_alpha: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">1</span>, <span style="color: #008000">8</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</span>), block_0_block_1_weight_g: R<span style="color: #AA22FF; font-weight: bold">.</span>Tensor((<span style="color: #008000">8</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), dtype<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #BA2121">&quot;float32&quot;</
# [('block.0.block.0.alpha', Tensor([1, 8, 1], "float32")), ('block.0.block.1.weight_g', Tensor([8, 1, 1], "float32")), ('block.0.block.1.weight_v', Tensor([8, 8, 7], "float32")), ('block.0.block.1.bias', Tensor([8], "float32")), ('block.0.block.2.alpha', Tensor([1, 8, 1], "float32")), ('block.0.block.3.weight_g', Tensor([8, 1, 1], "float32")), ('block.0.block.3.weight_v', Tensor([8, 8, 1], "float32")), ('block.0.block.3.bias', Tensor([8], "float32")), ('block.1.block.0.alpha', Tensor([1, 8, 1], "float32")), ('block.1.block.1.weight_g', Tensor([8, 1, 1], "float32")), ('block.1.block.1.weight_v', Tensor([8, 8, 7], "float32")), ('block.1.block.1.bias', Tensor([8], "float32")), ('block.1.block.2.alpha', Tensor([1, 8, 1], "float32")), ('block.1.block.3.weight_g', Tensor([8, 1, 1], "float32")), ('block.1.block.3.weight_v', Tensor([8, 8, 1], "float32")), ('block.1.block.3.bias', Tensor([8], "float32")), ('block.2.block.0.alpha', Tensor([1, 8, 1], "float32")), ('block.2.block.1.weight_g', Tensor([8, 1, 1], "float32")), ('block.2.block.1.weight_v', Tensor([8, 8, 7], "float32")), ('block.2.block.1.bias', Tensor([8], "float32")), ('block.2.block.2.alpha', Tensor([1, 8, 1], "float32")), ('block.2.block.3.weight_g', Tensor([8, 1, 1], "float32")), ('block.2.block.3.weight_v', Tensor([8, 8, 1], "float32")), ('block.2.block.3.bias', Tensor([8], "float32")), ('block.3.alpha', Tensor([1, 8, 1], "float32")), ('block.4.weight_g', Tensor([16, 1, 1], "float32")), ('block.4.weight_v', Tensor([16, 8, 2], "float32")), ('block.4.bias', Tensor([16], "float32"))]

# %%
class Encoder(nn.Module):
    def __init__(self,         
        d_model: int = 64,
        strides: list = [2, 4, 8, 8],
        d_latent: int = 64,
    ):

        self.block = [
            WNConv1d(1, d_model, kernel_size=7, padding=3)
        ]

        for stride in strides:
            d_model *= 2
            self.block += [EncoderBlock(d_model, stride=stride)]

        # Create last convolution
        self.block += [
            Snake1d(d_model),
            WNConv1d(d_model, d_latent, kernel_size=3, padding=1),
        ]

        # Wrap black into nn.Sequential
        self.block = nn.ModuleList(self.block)

    def forward(self, x):
        for layer in self.block:
            x = layer(x)
        return x

# %%
from typing import List, Union


class DAC(nn.Module):
    def __init__(
        self,
        encoder_dim: int = 64,
        encoder_rates: List[int] = [2, 4, 8, 8],
        latent_dim: int = None,
        decoder_dim: int = 1536,
        decoder_rates: List[int] = [8, 8, 4, 2],
        n_codebooks: int = 9,
        codebook_size: int = 1024,
        codebook_dim: Union[int, list] = 8,
        quantizer_dropout: bool = False,
        sample_rate: int = 44100,
    ):
        self.encoder_dim = encoder_dim
        self.encoder_rates = encoder_rates
        self.decoder_dim = decoder_dim
        self.decoder_rates = decoder_rates
        self.sample_rate = sample_rate

        if latent_dim is None:
            latent_dim = encoder_dim * (2 ** len(encoder_rates))

        self.latent_dim = latent_dim

        self.hop_length = np.prod(encoder_rates)
        self.encoder = Encoder(encoder_dim, encoder_rates, latent_dim)

    def forward(self, x):
        x = self.encoder(x)
        return x

    
mod_from_relax, params_from_relax = DAC().export_tvm(
    {"forward": {"x": nn.spec.Tensor((32, 1, 100000), "float32")}}, debug=True
)
mod_from_relax.show()
print(params_from_relax)
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import relax as R</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func(private<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">snake</span>(reshape: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">64</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">100000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), encoder_block_1_block_0_block_0_alpha: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">64</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), snake_compute: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">64</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">100000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         <span style="color: #008000; font-weight: bold">for</span> i, j, k <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">64</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">100000</span>)):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #AA22FF; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;snake_compute&quot;</span>):
#                 v_i, v_j, v_k <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>axis<span style="color: #AA22FF; font-weight: bold">.</span>remap(<span style="color: #BA2121">&quot;SSS&quot;</span>, [i, j, k])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>reads(reshape[v_i, v_j, v_k], encoder_block_1_block_0_block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)])
#                 T<span style="color: #AA22FF; font-weight: bold">.</span>writes(snake_compute[v_i, v_j, v_k])
#                 snake_compute[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">=</span> reshape[v_i, v_j, v_k] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0</span>) <span style="color: #AA22FF; font-weight: bold">/</span> (encoder_block_1_block_0_block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">+</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">1.0000000000000001e-09</span>)) <span style="color: #AA22FF; font-weight: bold">*</span> T<span style="color: #AA22FF; font-weight: bold">.</span>pow(T<span style="color: #AA22FF; font-weight: bold">.</span>sin(encoder_block_1_block_0_block_0_alpha[T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>), v_j, T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">0</span>)] <span style="color: #AA22FF; font-weight: bold">*</span> reshape[v_i, v_j, v_k]), T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">2.0</span>))
#
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func(private<span style="color: #AA22FF; font-weight: bold">=</span><span style="color: #008000; font-weight: bold">True</span>)
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">snake1</span>(reshape14: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">128</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">50000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), encoder_block_2_block_0_block_0_alpha: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">128</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">1</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>), snake_compute: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">128</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">50000</span>)), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         <span style="color: #008000; font-weight: bold">for</span> i, j, k <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">32</span>), T<span style="color: #AA22FF; font-weight: bold">.</span>int64(<span style="color: #008000">128</span>), T<span st
# [('encoder.block.0.weight_g', Tensor([64, 1, 1], "float32")), ('encoder.block.0.weight_v', Tensor([64, 1, 7], "float32")), ('encoder.block.0.bias', Tensor([64], "float32")), ('encoder.block.1.block.0.block.0.alpha', Tensor([1, 64, 1], "float32")), ('encoder.block.1.block.0.block.1.weight_g', Tensor([64, 1, 1], "float32")), ('encoder.block.1.block.0.block.1.weight_v', Tensor([64, 64, 7], "float32")), ('encoder.block.1.block.0.block.1.bias', Tensor([64], "float32")), ('encoder.block.1.block.0.block.2.alpha', Tensor([1, 64, 1], "float32")), ('encoder.block.1.block.0.block.3.weight_g', Tensor([64, 1, 1], "float32")), ('encoder.block.1.block.0.block.3.weight_v', Tensor([64, 64, 1], "float32")), ('encoder.block.1.block.0.block.3.bias', Tensor([64], "float32")), ('encoder.block.1.block.1.block.0.alpha', Tensor([1, 64, 1], "float32")), ('encoder.block.1.block.1.block.1.weight_g', Tensor([64, 1, 1], "float32")), ('encoder.block.1.block.1.block.1.weight_v', Tensor([64, 64, 7], "float32")), ('encoder.block.1.block.1.block.1.bias', Tensor([64], "float32")), ('encoder.block.1.block.1.block.2.alpha', Tensor([1, 64, 1], "float32")), ('encoder.block.1.block.1.block.3.weight_g', Tensor([64, 1, 1], "float32")), ('encoder.block.1.block.1.block.3.weight_v', Tensor([64, 64, 1], "float32")), ('encoder.block.1.block.1.block.3.bias', Tensor([64], "float32")), ('encoder.block.1.block.2.block.0.alpha', Tensor([1, 64, 1], "float32")), ('encoder.block.1.block.2.block.1.weight_g', Tensor([64, 1, 1], "float32")), ('encoder.block.1.block.2.block.1.weight_v', Tensor([64, 64, 7], "float32")), ('encoder.block.1.block.2.block.1.bias', Tensor([64], "float32")), ('encoder.block.1.block.2.block.2.alpha', Tensor([1, 64, 1], "float32")), ('encoder.block.1.block.2.block.3.weight_g', Tensor([64, 1, 1], "float32")), ('encoder.block.1.block.2.block.3.weight_v', Tensor([64, 64, 1], "float32")), ('encoder.block.1.block.2.block.3.bias', Tensor([64], "float32")), ('encoder.block.1.block.3.alpha', Tensor([1, 64, 1], "float32")), ('encoder.block.1.block.4.weight_g', Tensor([128, 1, 1], "float32")), ('encoder.block.1.block.4.weight_v', Tensor([128, 64, 4], "float32")), ('encoder.block.1.block.4.bias', Tensor([128], "float32")), ('encoder.block.2.block.0.block.0.alpha', Tensor([1, 128, 1], "float32")), ('encoder.block.2.block.0.block.1.weight_g', Tensor([128, 1, 1], "float32")), ('encoder.block.2.block.0.block.1.weight_v', Tensor([128, 128, 7], "float32")), ('encoder.block.2.block.0.block.1.bias', Tensor([128], "float32")), ('encoder.block.2.block.0.block.2.alpha', Tensor([1, 128, 1], "float32")), ('encoder.block.2.block.0.block.3.weight_g', Tensor([128, 1, 1], "float32")), ('encoder.block.2.block.0.block.3.weight_v', Tensor([128, 128, 1], "float32")), ('encoder.block.2.block.0.block.3.bias', Tensor([128], "float32")), ('encoder.block.2.block.1.block.0.alpha', Tensor([1, 128, 1], "float32")), ('encoder.block.2.block.1.block.1.weight_g', Tensor([128, 1, 1], "float32")), ('encoder.block.2.block.1.block.1.weight_v', Tensor([128, 128, 7], "float32")), ('encoder.block.2.block.1.block.1.bias', Tensor([128], "float32")), ('encoder.block.2.block.1.block.2.alpha', Tensor([1, 128, 1], "float32")), ('encoder.block.2.block.1.block.3.weight_g', Tensor([128, 1, 1], "float32")), ('encoder.block.2.block.1.block.3.weight_v', Tensor([128, 128, 1], "float32")), ('encoder.block.2.block.1.block.3.bias', Tensor([128], "float32")), ('encoder.block.2.block.2.block.0.alpha', Tensor([1, 128, 1], "float32")), ('encoder.block.2.block.2.block.1.weight_g', Tensor([128, 1, 1], "float32")), ('encoder.block.2.block.2.block.1.weight_v', Tensor([128, 128, 7], "float32")), ('encoder.block.2.block.2.block.1.bias', Tensor([128], "float32")), ('encoder.block.2.block.2.block.2.alpha', Tensor([1, 128, 1], "float32")), ('encoder.block.2.block.2.block.3.weight_g', Tensor([128, 1, 1], "float32")), ('encoder.block.2.block.2.block.3.weight_v', Tensor([128, 128, 1], "float32")), ('encoder.block.2.block.2.block.3.bias', Tens ...

# %%
import torch

file_path = "weights.pth"
state_dict = torch.load(file_path, map_location=torch.device('cpu'))["state_dict"]

# Check if the loaded data is a state dictionary
if isinstance(state_dict, dict):
    # Iterate over the state dictionary to print each weight name and its shape
    print("Weights and their corresponding shapes:")
    for name, tensor in state_dict.items():
        # Check if the item is a tensor to print its shape
        if isinstance(tensor, torch.Tensor):
            print(f"{name}: {tensor.shape}")
        else:
            print(f"{name}: Not a tensor, possibly another data type.")
else:
    print("Loaded file does not contain a state dictionary.")
# Out:
# Weights and their corresponding shapes:
# encoder.block.0.bias: torch.Size([64])
# encoder.block.0.weight_g: torch.Size([64, 1, 1])
# encoder.block.0.weight_v: torch.Size([64, 1, 7])
# encoder.block.1.block.0.block.0.alpha: torch.Size([1, 64, 1])
# encoder.block.1.block.0.block.1.bias: torch.Size([64])
# encoder.block.1.block.0.block.1.weight_g: torch.Size([64, 1, 1])
# encoder.block.1.block.0.block.1.weight_v: torch.Size([64, 64, 7])
# encoder.block.1.block.0.block.2.alpha: torch.Size([1, 64, 1])
# encoder.block.1.block.0.block.3.bias: torch.Size([64])
# encoder.block.1.block.0.block.3.weight_g: torch.Size([64, 1, 1])
# encoder.block.1.block.0.block.3.weight_v: torch.Size([64, 64, 1])
# encoder.block.1.block.1.block.0.alpha: torch.Size([1, 64, 1])
# encoder.block.1.block.1.block.1.bias: torch.Size([64])
# encoder.block.1.block.1.block.1.weight_g: torch.Size([64, 1, 1])
# encoder.block.1.block.1.block.1.weight_v: torch.Size([64, 64, 7])
# encoder.block.1.block.1.block.2.alpha: torch.Size([1, 64, 1])
# encoder.block.1.block.1.block.3.bias: torch.Size([64])
# encoder.block.1.block.1.block.3.weight_g: torch.Size([64, 1, 1])
# encoder.block.1.block.1.block.3.weight_v: torch.Size([64, 64, 1])
# encoder.block.1.block.2.block.0.alpha: torch.Size([1, 64, 1])
# encoder.block.1.block.2.block.1.bias: torch.Size([64])
# encoder.block.1.block.2.block.1.weight_g: torch.Size([64, 1, 1])
# encoder.block.1.block.2.block.1.weight_v: torch.Size([64, 64, 7])
# encoder.block.1.block.2.block.2.alpha: torch.Size([1, 64, 1])
# encoder.block.1.block.2.block.3.bias: torch.Size([64])
# encoder.block.1.block.2.block.3.weight_g: torch.Size([64, 1, 1])
# encoder.block.1.block.2.block.3.weight_v: torch.Size([64, 64, 1])
# encoder.block.1.block.3.alpha: torch.Size([1, 64, 1])
# encoder.block.1.block.4.bias: torch.Size([128])
# encoder.block.1.block.4.weight_g: torch.Size([128, 1, 1])
# encoder.block.1.block.4.weight_v: torch.Size([128, 64, 4])
# encoder.block.2.block.0.block.0.alpha: torch.Size([1, 128, 1])
# encoder.block.2.block.0.block.1.bias: torch.Size([128])
# encoder.block.2.block.0.block.1.weight_g: torch.Size([128, 1, 1])
# encoder.block.2.block.0.block.1.weight_v: torch.Size([128, 128, 7])
# encoder.block.2.block.0.block.2.alpha: torch.Size([1, 128, 1])
# encoder.block.2.block.0.block.3.bias: torch.Size([128])
# encoder.block.2.block.0.block.3.weight_g: torch.Size([128, 1, 1])
# encoder.block.2.block.0.block.3.weight_v: torch.Size([128, 128, 1])
# encoder.block.2.block.1.block.0.alpha: torch.Size([1, 128, 1])
# encoder.block.2.block.1.block.1.bias: torch.Size([128])
# encoder.block.2.block.1.block.1.weight_g: torch.Size([128, 1, 1])
# encoder.block.2.block.1.block.1.weight_v: torch.Size([128, 128, 7])
# encoder.block.2.block.1.block.2.alpha: torch.Size([1, 128, 1])
# encoder.block.2.block.1.block.3.bias: torch.Size([128])
# encoder.block.2.block.1.block.3.weight_g: torch.Size([128, 1, 1])
# encoder.block.2.block.1.block.3.weight_v: torch.Size([128, 128, 1])
# encoder.block.2.block.2.block.0.alpha: torch.Size([1, 128, 1])
# encoder.block.2.block.2.block.1.bias: torch.Size([128])
# encoder.block.2.block.2.block.1.weight_g: torch.Size([128, 1, 1])
# encoder.block.2.block.2.block.1.weight_v: torch.Size([128, 128, 7])
# encoder.block.2.block.2.block.2.alpha: torch.Size([1, 128, 1])
# encoder.block.2.block.2.block.3.bias: torch.Size([128])
# encoder.block.2.block.2.block.3.weight_g: torch.Size([128, 1, 1])
# encoder.block.2.block.2.block.3.weight_v: torch.Size([128, 128, 1])
# encoder.block.2.block.3.alpha: torch.Size([1, 128, 1])
# encoder.block.2.block.4.bias: torch.Size([256])
# encoder.block.2.block.4.weight_g: torch.Size([256, 1, 1])
# encoder.block.2.block.4.weight_v: torch.Size([256, 128, 8])
# encoder.block.3.block.0.block.0.alpha: torch.Size([1, 256, 1])
# encoder.block.3.block.0.block.1.bias: torch.Size([256])
# encoder.block.3.block.0.block.1.weight_g: torch.Size([256, 1, 1])
# encoder.block.3.block.0.block.1.weight_v: torch.Size([256, 256, 7])
# encoder.block.3.block.0.block.2.alpha: torch.Size([1, 256, 1])
# encoder.block.3.block.0.block.3.bias: torch.Size([256])
# encoder.block.3.block.0.block.3.weight_g: torch.Size([256, 1, 1])
# encoder.block.3.block.0.block.3.weight_v: torch.Size([256, 256, 1])
# encoder.block.3.block.1.block.0.alpha: torch.Size([1, 256, 1])
# encoder.block.3.block.1.block.1.bias: torch.Size([256])
# encoder.block.3.block.1.block.1.weight_g: torch.Size([256, 1, 1])
# encoder.block.3.block.1.block.1.weight_v: torch.Size([256, 256, 7])
# encoder.block.3.block.1.block.2.alpha: torch.Size([1, 256, 1])
# encoder.block.3.block.1.block.3.bias: torch.Size([256])
# encoder.block.3.block.1.block.3.weight_g: torch.Size([256, 1, 1])
# encoder.block.3.block.1.block.3.weight_v: torch.Size([256, 256, 1])
# encoder.block.3.block.2.block.0.alpha: torch.Size([1, 256, 1])
# encoder.block.3.block.2.block.1.bias: torch.Size([256])
# encoder.block.3.block.2.block.1.weight_g: torch.Size([256, 1, 1])
# encoder.block.3.block.2.block.1.weight_v: torch.Size([256, 256, 7])
# encoder.block.3.block.2.block.2.alpha: torch.Size([1, 256, 1])
# encoder.block.3.block.2.block.3.bias: torch.Size([256])
# encoder.block.3.block.2.block.3.weight_g: torch.Size([256, 1, 1])
# encoder.block.3.block.2.block.3.weight_v: torch.Size([256, 256, 1])
# encoder.block.3.block.3.alpha: torch.Size([1, 256, 1])
# encoder.block.3.block.4.bias: torch.Size([512])
# encoder.block.3.block.4.weight_g: torch.Size([512, 1, 1])
# encoder.block.3.block.4.weight_v: torch.Size([512, 256, 16])
# encoder.block.4.block.0.block.0.alpha: torch.Size([1, 512, 1])
# encoder.block.4.block.0.block.1.bias: torch.Size([512])
# encoder.block.4.block.0.block.1.weight_g: torch.Size([512, 1, 1])
# encoder.block.4.block.0.block.1.weight_v: torch.Size([512, 512, 7])
# encoder.block.4.block.0.block.2.alpha: torch.Size([1, 512, 1])
# encoder.block.4.block.0.block.3.bias: torch.Size([512])
# encoder.block.4.block.0.block.3.weight_g: torch.Size([512, 1, 1])
# encoder.block.4.block.0.block.3.weight_v: torch.Size([512, 512, 1])
# encoder.block.4.block.1.block.0.alpha: torch.Size([1, 512, 1])
# encoder.block.4.block.1.block.1.bias: torch.Size([512])
# encoder.block.4.block.1.block.1.weight_g: torch.Size([512, 1, 1])
# encoder.block.4.block.1.block.1.weight_v: torch.Size([512, 512, 7])
# encoder.block.4.block.1.block.2.alpha: torch.Size([1, 512, 1])
# encoder.block.4.block.1.block.3.bias: torch.Size([512])
# encoder.block.4.block.1.block.3.weight_g: torch.Size([512, 1, 1])
# encoder.block.4.block.1.block.3.weight_v: torch.Size([512, 512, 1])
# encoder.block.4.block.2.block.0.alpha: torch.Size([1, 512, 1])
# encoder.block.4.block.2.block.1.bias: torch.Size([512])
# encoder.block.4.block.2.block.1.weight_g: torch.Size([512, 1, 1])
# encoder.block.4.block.2.block.1.weight_v: torch.Size([512, 512, 7])
# encoder.block.4.block.2.block.2.alpha: torch.Size([1, 512, 1])
# encoder.block.4.block.2.block.3.bias: torch.Size([512])
# encoder.block.4.block.2.block.3.weight_g: torch.Size([512, 1, 1])
# encoder.block.4.block.2.block.3.weight_v: torch.Size([512, 512, 1])
# encoder.block.4.block.3.alpha: torch.Size([1, 512, 1])
# encoder.block.4.block.4.bias: torch.Size([1024])
# encoder.block.4.block.4.weight_g: torch.Size([1024, 1, 1])
# encoder.block.4.block.4.weight_v: torch.Size([1024, 512, 16])
# encoder.block.5.alpha: torch.Size([1, 1024, 1])
# encoder.block.6.bias: torch.Size([1024])
# encoder.block.6.weight_g: torch.Size([1024, 1, 1])
# encoder.block.6.weight_v: torch.Size([1024, 1024, 3])
# quantizer.quantizers.0.in_proj.bias: torch.Size([8])
# quantizer.quantizers.0.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.0.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.0.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.0.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.0.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.0.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.1.in_proj.bias: torch.Size([8])
# quantizer.quantizers.1.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.1.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.1.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.1.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.1.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.1.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.2.in_proj.bias: torch.Size([8])
# quantizer.quantizers.2.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.2.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.2.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.2.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.2.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.2.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.3.in_proj.bias: torch.Size([8])
# quantizer.quantizers.3.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.3.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.3.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.3.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.3.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.3.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.4.in_proj.bias: torch.Size([8])
# quantizer.quantizers.4.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.4.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.4.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.4.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.4.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.4.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.5.in_proj.bias: torch.Size([8])
# quantizer.quantizers.5.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.5.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.5.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.5.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.5.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.5.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.6.in_proj.bias: torch.Size([8])
# quantizer.quantizers.6.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.6.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.6.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.6.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.6.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.6.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.7.in_proj.bias: torch.Size([8])
# quantizer.quantizers.7.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.7.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.7.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.7.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.7.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.7.codebook.weight: torch.Size([1024, 8])
# quantizer.quantizers.8.in_proj.bias: torch.Size([8])
# quantizer.quantizers.8.in_proj.weight_g: torch.Size([8, 1, 1])
# quantizer.quantizers.8.in_proj.weight_v: torch.Size([8, 1024, 1])
# quantizer.quantizers.8.out_proj.bias: torch.Size([1024])
# quantizer.quantizers.8.out_proj.weight_g: torch.Size([1024, 1, 1])
# quantizer.quantizers.8.out_proj.weight_v: torch.Size([1024, 8, 1])
# quantizer.quantizers.8.codebook.weight: torch.Size([1024, 8])
# decoder.model.0.bias: torch.Size([1536])
# decoder.model.0.weight_g: torch.Size([1536, 1, 1])
# decoder.model.0.weight_v: torch.Size([1536, 1024, 7])
# decoder.model.1.block.0.alpha: torch.Size([1, 1536, 1])
# decoder.model.1.block.1.bias: torch.Size([768])
# decoder.model.1.block.1.weight_g: torch.Size([1536, 1, 1])
# decoder.model.1.block.1.weight_v: torch.Size([1536, 768, 16])
# decoder.model.1.block.2.block.0.alpha: torch.Size([1, 768, 1])
# decoder.model.1.block.2.block.1.bias: torch.Size([768])
# decoder.model.1.block.2.block.1.weight_g: torch.Size([768, 1, 1])
# decoder.model.1.block.2.block.1.weight_v: torch.Size([768, 768, 7])
# decoder.model.1.block.2.block.2.alpha: torch.Size([1, 768, 1])
# decoder.model.1.block.2.block.3.bias: torch.Size([768])
# decoder.model.1.block.2.block.3.weight_g: torch.Size([768, 1, 1])
# decoder.model.1.block.2.block.3.weight_v: torch.Size([768, 768, 1])
# decoder.model.1.block.3.block.0.alpha: torch.Size([1, 768, 1])
# decoder.model.1.block.3.block.1.bias: torch.Size([768])
# decoder.model.1.block.3.block.1.weight_g: torch.Size([768, 1, 1])
# decoder.model.1.block.3.block.1.weight_v: torch.Size([768, 768, 7])
# decoder.model.1.block.3.block.2.alpha: torch.Size([1, 768, 1])
# decoder.model.1.block.3.block.3.bias: torch.Size([768])
# decoder.model.1.block.3.block.3.weight_g: torch.Size([768, 1, 1])
# decoder.model.1.block.3.block.3.weight_v: torch.Size([768, 768, 1])
# decoder.model.1.block.4.block.0.alpha: torch.Size([1, 768, 1])
# decoder.model.1.block.4.block.1.bias: torch.Size([768])
# decoder.model.1.block.4.block.1.weight_g: torch.Size([768, 1, 1])
# decoder.model.1.block.4.block.1.weight_v: torch.Size([768, 768, 7])
# decoder.model.1.block.4.block.2.alpha: torch.Size([1, 768, 1])
# decoder.model.1.block.4.block.3.bias: torch.Size([768])
# decoder.model.1.block.4.block.3.weight_g: torch.Size([768, 1, 1])
# decoder.model.1.block.4.block.3.weight_v: torch.Size([768, 768, 1])
# decoder.model.2.block.0.alpha: torch.Size([1, 768, 1])
# decoder.model.2.block.1.bias: torch.Size([384])
# decoder.model.2.block.1.weight_g: torch.Size([768, 1, 1])
# decoder.model.2.block.1.weight_v: torch.Size([768, 384, 16])
# decoder.model.2.block.2.block.0.alpha: torch.Size([1, 384, 1])
# decoder.model.2.block.2.block.1.bias: torch.Size([384])
# decoder.model.2.block.2.block.1.weight_g: torch.Size([384, 1, 1])
# decoder.model.2.block.2.block.1.weight_v: torch.Size([384, 384, 7])
# decoder.model.2.block.2.block.2.alpha: torch.Size([1, 384, 1])
# decoder.model.2.block.2.block.3.bias: torch.Size([384])
# decoder.model.2.block.2.block.3.weight_g: torch.Size([384, 1, 1])
# decoder.model.2.block.2.block.3.weight_v: torch.Size([384, 384, 1])
# decoder.model.2.block.3.block.0.alpha: torch.Size([1, 384, 1])
# decoder.model.2.block.3.block.1.bias: torch.Size([384])
# decoder.model.2.block.3.block.1.weight_g: torch.Size([384, 1, 1])
# decoder.model.2.block.3.block.1.weight_v: torch.Size([384, 384, 7])
# decoder.model.2.block.3.block.2.alpha: torch.Size([1, 384, 1])
# decoder.model.2.block.3.block.3.bias: torch.Size([384])
# decoder.model.2.block.3.block.3.weight_g: torch.Size([384, 1, 1])
# decoder.model.2.block.3.block.3.weight_v: torch.Size([384, 384, 1])
# decoder.model.2.block.4.block.0.alpha: torch.Size([1, 384, 1])
# decoder.model.2.block.4.block.1.bias: torch.Size([384])
# decoder.model.2.block.4.block.1.weight_g: torch.Size([384, 1, 1])
# decoder.model.2.block.4.block.1.weight_v: torch.Size([384, 384, 7])
# decoder.model.2.block.4.block.2.alpha: torch.Size([1, 384, 1])
# decoder.model.2.block.4.block.3.bias: torch.Size([384])
# decoder.model.2.block.4.block.3.weight_g: torch.Size([384, 1, 1])
# decoder.model.2.block.4.block.3.weight_v: torch.Size([384, 384, 1])
# decoder.model.3.block.0.alpha: torch.Size([1, 384, 1])
# decoder.model.3.block.1.bias: torch.Size([192])
# decoder.model.3.block.1.weight_g: torch.Size([384, 1, 1])
# decoder.model.3.block.1.weight_v: torch.Size([384, 192, 8])
# decoder.model.3.block.2.block.0.alpha: torch.Size([1, 192, 1])
# decoder.model.3.block.2.block.1.bias: torch.Size([192])
# decoder.model.3.block.2.block.1.weight_g: torch.Size([192, 1, 1])
# decoder.model.3.block.2.block.1.weight_v: torch.Size([192, 192, 7])
# decoder.model.3.block.2.block.2.alpha: torch.Size([1, 192, 1])
# decoder.model.3.block.2.block.3.bias: torch.Size([192])
# decoder.model.3.block.2.block.3.weight_g: torch.Size([192, 1, 1])
# decoder.model.3.block.2.block.3.weight_v: torch.Size([192, 192, 1])
# decoder.model.3.block.3.block.0.alpha: torch.Size([1, 192, 1])
# decoder.model.3.block.3.block.1.bias: torch.Size([192])
# decoder.model.3.block.3.block.1.weight_g: torch.Size([192, 1, 1])
# decoder.model.3.block.3.block.1.weight_v: torch.Size([192, 192, 7])
# decoder.model.3.block.3.block.2.alpha: torch.Size([1, 192, 1])
# decoder.model.3.block.3.block.3.bias: torch.Size([192])
# decoder.model.3.block.3.block.3.weight_g: torch.Size([192, 1, 1])
# decoder.model.3.block.3.block.3.weight_v: torch.Size([192, 192, 1])
# decoder.model.3.block.4.block.0.alpha: torch.Size([1, 192, 1])
# decoder.model.3.block.4.block.1.bias: torch.Size([192])
# decoder.model.3.block.4.block.1.weight_g: torch.Size([192, 1, 1])
# decoder.model.3.block.4.block.1.weight_v: torch.Size([192, 192, 7])
# decoder.model.3.block.4.block.2.alpha: torch.Size([1, 192, 1])
# decoder.model.3.block.4.block.3.bias: torch.Size([192])
# decoder.model.3.block.4.block.3.weight_g: torch.Size([192, 1, 1])
# decoder.model.3.block.4.block.3.weight_v: torch.Size([192, 192, 1])
# decoder.model.4.block.0.alpha: torch.Size([1, 192, 1])
# decoder.model.4.block.1.bias: torch.Size([96])
# decoder.model.4.block.1.weight_g: torch.Size([192, 1, 1])
# decoder.model.4.block.1.weight_v: torch.Size([192, 96, 4])
# decoder.model.4.block.2.block.0.alpha: torch.Size([1, 96, 1])
# decoder.model.4.block.2.block.1.bias: torch.Size([96])
# decoder.model.4.block.2.block.1.weight_g: torch.Size([96, 1, 1])
# decoder.model.4.block.2.block.1.weight_v: torch.Size([96, 96, 7])
# decoder.model.4.block.2.block.2.alpha: torch.Size([1, 96, 1])
# decoder.model.4.block.2.block.3.bias: torch.Size([96])
# decoder.model.4.block.2.block.3.weight_g: torch.Size([96, 1, 1])
# decoder.model.4.block.2.block.3.weight_v: torch.Size([96, 96, 1])
# decoder.model.4.block.3.block.0.alpha: torch.Size([1, 96, 1])
# decoder.model.4.block.3.block.1.bias: torch.Size([96])
# decoder.model.4.block.3.block.1.weight_g: torch.Size([96, 1, 1])
# decoder.model.4.block.3.block.1.weight_v: torch.Size([96, 96, 7])
# decoder.model.4.block.3.block.2.alpha: torch.Size([1, 96, 1])
# decoder.model.4.block.3.block.3.bias: torch.Size([96])
# decoder.model.4.block.3.block.3.weight_g: torch.Size([96, 1, 1])
# decoder.model.4.block.3.block.3.weight_v: torch.Size([96, 96, 1])
# decoder.model.4.block.4.block.0.alpha: torch.Size([1, 96, 1])
# decoder.model.4.block.4.block.1.bias: torch.Size([96])
# decoder.model.4.block.4.block.1.weight_g: torch.Size([96, 1, 1])
# decoder.model.4.block.4.block.1.weight_v: torch.Size([96, 96, 7])
# decoder.model.4.block.4.block.2.alpha: torch.Size([1, 96, 1])
# decoder.model.4.block.4.block.3.bias: torch.Size([96])
# decoder.model.4.block.4.block.3.weight_g: torch.Size([96, 1, 1])
# decoder.model.4.block.4.block.3.weight_v: torch.Size([96, 96, 1])
# decoder.model.5.alpha: torch.Size([1, 96, 1])
# decoder.model.6.bias: torch.Size([1])
# decoder.model.6.weight_g: torch.Size([1, 1, 1])
# decoder.model.6.weight_v: torch.Size([1, 96, 7])
# /var/folders/50/mzqbqxqj5fddcby2mg3h334c0000gp/T/ipykernel_25238/1964811832.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(file_path, map_location=torch.device('cpu'))["state_dict"]
